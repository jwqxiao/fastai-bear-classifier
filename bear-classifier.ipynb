# %%
# !pip install -q voila
import voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Config option `kernel_spec_manager_class` not recognized by `EnableServerExtensionApp`.
# Enabling: voila
# - Writing config: /opt/conda/etc/jupyter
#     - Validating...
#       voila 0.5.4 OK

# %%
from fastai.vision.all import *
learn_inf = load_learner('/kaggle/input/bear-classifier-model/export.pkl')

# %%
# !pip install -q ipywidgets

# %%
import ipywidgets as widgets

# %%
btn_upload = widgets.FileUpload()

# %%
out_pl = widgets.Output()

# %%
lbl_pred = widgets.Label()

# %%
btn_run = widgets.Button(description="Classify")

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128, 128))
    pred, pred_idx, probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}. Probability: {probs[pred_idx]: .04f}'
    
btn_run.on_click(on_click_classify)

# %%
from IPython.display import display
layout = widgets.VBox([widgets.Label('Select your bear!'), btn_upload, btn_run, out_pl, lbl_pred])
display(layout)
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={'cat.jpg': {'metadata': {'name': 'cat.jpg',…
